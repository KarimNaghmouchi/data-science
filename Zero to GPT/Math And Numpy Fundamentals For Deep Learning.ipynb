# %%
v = [0,1]

# %%
import numpy as np

v = np.array([1,1])
print(v)
# Out:
# [1 1]

# %%
m = np.array([[1,1],[1,0]])
m
# Out:
# array([[1, 1],
#        [1, 0]])

# %%
import matplotlib.pyplot as plt
plt.xlim(0,3)
plt.ylim(0,3)

plt.arrow(0,0,v[0],v[1],head_width=0.1,head_length=0.1,color='blue')

# %% [markdown]
# $$||x||_{2} = \sqrt{x_{1}^{2} + x_{2}^{2} + \cdots + x_{n}^{2}}$$

# %%
np.sqrt(np.sum(v**2))
# Out:
# np.float64(1.4142135623730951)

# %%
v = np.array([0,1,1])
print(v)
# Out:
# [0 1 1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim([0,3])
ax.set_ylim([0,3])
ax.set_zlim([0,3])

ax.quiver(0,0,0,v[0],v[1],v[2],color='blue')

# %%
v = np.array([0,1,2,3,4])

# %%
v[3]
# Out:
# np.int64(3)

# %%
v = np.array([1,1]) * .5
print(v)
# Out:
# [0.5 0.5]

# %%
plt.xlim(0,3)
plt.ylim(0,3)

plt.arrow(0,0,v[0],v[1],head_width=0.1,head_length=0.1,color='blue')

# %%
v = np.array([1,1]) + np.array([1,0])
v
# Out:
# array([2, 1])

# %%
plt.xlim(0,3)
plt.ylim(0,3)
plt.arrow(0,0,v[0],v[1],head_width=0.1,head_length=0.1,color='blue')

# %%
v1 = np.array([0,1])
v2 = np.array([1,0])

plt.xlim(-1,3)
plt.ylim(-1,3)

plt.quiver([0,0],[0,0],[v1[0],v2[0]],[v1[1],v2[1]],angles='xy',scale_units='xy',scale=1,color=['blue','red'])

# %%
#.3 , 1
v1 + v2 * 0.3
# Out:
# array([0.3, 1. ])

# %%
np.dot(v1,v2)
# Out:
# np.int64(0)

# %%
v1 = np.array([0,1])
v2 = np.array([0.1,1])

plt.xlim(-1,3)
plt.ylim(-1,3)

plt.quiver([0,0],[0,0],[v1[0],v2[0]],[v1[1],v2[1]],angles='xy',scale_units='xy',scale=1,color=['blue','red'])

# %%
np.dot(v1,v2)
# Out:
# np.float64(1.0)

# %%
v1 = np.array([1,0])
v2 = np.array([0,1])

#2,1

2*v1 + 1*v2
# Out:
# array([2, 1])

# %%
M = np.array([[0,1,2],[1,4,2],[3,1,0]])
M
# Out:
# array([[0, 1, 2],
#        [1, 4, 2],
#        [3, 1, 0]])

# %%
M.shape
# Out:
# (3, 3)

# %%
M[0,0]
# Out:
# np.int64(0)

# %%
M[0]
# Out:
# array([0, 1, 2])

# %%
M[:,0]
# Out:
# array([0, 1, 3])

# %%
M[:2,:2]
# Out:
# array([[0, 1],
#        [1, 4]])

# %%
M[0,0] = 10
M
# Out:
# array([[10,  1,  2],
#        [ 1,  4,  2],
#        [ 3,  1,  0]])

# %% [markdown]
# $\hat{y}=wx+ b$

# %%
import pandas as pd
#Read in the data
data = pd.read_csv('clean_weather.csv')
#Fill the missing values in the data with past values
data= data.ffill()
data.head(5)
# Out:
#    Unnamed: 0  tmax  tmin  rain  tmax_tomorrow
# 0  1970-01-01  60.0  35.0   0.0           52.0
# 1  1970-01-02  52.0  39.0   0.0           52.0
# 2  1970-01-03  52.0  35.0   0.0           53.0
# 3  1970-01-04  53.0  36.0   0.0           52.0
# 4  1970-01-05  52.0  35.0   0.0           50.0

# %% [markdown]
# $$\hat{y} = w_{1}x_{1} + w_{2}x_{2} + w_{3}x_{3} + b $$

# %%
w1 = .7
w2 = .3
w3 = .1
b = 10

w1*60+w2*35+w3*0+b
# Out:
# 62.5

# %%
w = np.array([.7,.3,.1])
x = np.array([60,35,0])
np.dot(w,x)+b
# Out:
# np.float64(62.5)

# %% [markdown]
# $$
# A \times B =
# \begin{bmatrix}
# a_{11} & a_{12} \\
# a_{21} & a_{22}
# \end{bmatrix}
# \times
# \begin{bmatrix}
# b_{11} & b_{12} \\
# b_{21} & b_{22}
# \end{bmatrix}
# =
# \begin{bmatrix}
# a_{11}b_{11} + a_{12}b_{21} & a_{11}b_{12} + a_{12}b_{22} \\
# a_{21}b_{11} + a_{22}b_{21} & a_{21}b_{12} + a_{22}b_{22}
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# A \times B =
# \begin{bmatrix}
# a_{11} & a_{12} \\
# a_{21} & a_{22}
# \end{bmatrix}
# \times
# \begin{bmatrix}
# b_{11} \\
# b_{21}
# \end{bmatrix}
# =
# \begin{bmatrix}
# a_{11}b_{11} + a_{12}b_{21} \\
# a_{21}b_{11} + a_{22}b_{21}
# \end{bmatrix}
# $$

# %% [markdown]
# ![Matrix Multiplication Animation](<matrix_mult.gif>)

# %%
X = data[["tmax", "tmin", "rain"]].iloc[:3].to_numpy()
X
# Out:
# array([[60., 35.,  0.],
#        [52., 39.,  0.],
#        [52., 35.,  0.]])

# %%
X.shape
# Out:
# (3, 3)

# %%
w.shape
# Out:
# (3,)

# %%
W = w.reshape(3,1)
W
# Out:
# array([[0.7],
#        [0.3],
#        [0.1]])

# %%
W.shape
# Out:
# (3, 1)

# %%
b =np.array([10])

# %%
X @ W + b
# Out:
# array([[62.5],
#        [58.1],
#        [56.9]])

# %% [markdown]
# $$ W = (X^T X)^{-1}X^TY$$

# %% [markdown]
# $X^T$

# %%
(W.T @ X.T + b).T
# Out:
# array([[62.5],
#        [58.1],
#        [56.9]])

# %%
X.T
# Out:
# array([[60., 52., 52.],
#        [35., 39., 35.],
#        [ 0.,  0.,  0.]])

# %%
np.allclose((W.T @ X.T).T, X @ W)
# Out:
# True

# %%
(W.T @ X.T).T
# Out:
# array([[52.5],
#        [48.1],
#        [46.9]])

# %%
X@W
# Out:
# array([[52.5],
#        [48.1],
#        [46.9]])

# %% [markdown]
# $(X^TX)^{-1}$

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.linalg.inv(X)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 np.linalg.inv(X)
#
# File c:\Users\Karim Naghmouchi\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\_linalg.py:609, in inv(a)
#     606 signature = 'D->D' if isComplexType(t) else 'd->d'
#     607 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     608               over='ignore', divide='ignore', under='ignore'):
# --> 609     ainv = _umath_linalg.inv(a, signature=signature)
#     610 return wrap(ainv.astype(result_t, copy=False))
#
# File c:\Users\Karim Naghmouchi\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\_linalg.py:104, in _raise_linalgerror_singular(err, flag)
#     103 def _raise_linalgerror_singular(err, flag):
# --> 104     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
np.linalg.inv(X+ .1*np.eye(3))
# Out:
# array([[ 0.07378611, -0.06604895,  0.        ],
#        [-0.09812987,  0.11341549,  0.        ],
#        [-4.02332472, -5.34996509, 10.        ]])

# %%
X+ .1 * np.eye(3)
# Out:
# array([[60.1, 35. ,  0. ],
#        [52. , 39.1,  0. ],
#        [52. , 35. ,  0.1]])

# %%
ridge = X+.1 * np.eye(3)
inverse = np.linalg.inv(ridge)
ridge @ inverse
# Out:
# array([[ 1.00000000e+00,  5.41233725e-16,  0.00000000e+00],
#        [ 1.06185910e-16,  1.00000000e+00,  0.00000000e+00],
#        [-1.12317084e-17,  5.25413240e-16,  1.00000000e+00]])

# %%
np.allclose(ridge @ inverse, np.eye(3))
# Out:
# True

# %%
Y = data[["tmax_tomorrow"]].iloc[:3].to_numpy()
W = np.linalg.inv(X.T@X+.1 * np.eye(x.shape[0])) @ X.T @ Y
W
# Out:
# array([[0.38283829],
#        [0.86270249],
#        [0.        ]])

# %%
X@W
# Out:
# array([[53.16488447],
#        [53.55298814],
#        [50.10217817]])

# %%
Y
# Out:
# array([[52.],
#        [52.],
#        [53.]])

# %%
b=np.array([10])

X @ W + b
# Out:
# array([[63.16488447],
#        [63.55298814],
#        [60.10217817]])

# %% [markdown]
# * The smaller array has all of its dimensions exactly matching the length dimensions of the larger array
# * Or the smaller array is length 1 in the non-matching dimensions.

# %%
(3,2)
(2,2)
# Out:
# (2, 2)

# %%
A = np.ones((5,1))
#This works
A + np.ones((1,1))
# Out:
# array([[2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.]])

# %%
A + np.ones((1))
# Out:
# array([[2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.]])

# %%
A+ np.ones((2,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 A+ np.ones((2,1))
#
# ValueError: operands could not be broadcast together with shapes (5,1) (2,1)

# %%
A.shape
# Out:
# (5, 1)

# %%
A* np.full((1,1),2)
# Out:
# array([[2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.]])

# %% [markdown]
# $y = x^2$

# %%
import matplotlib.pyplot as plt
xs = np.arange(-10,10,0.1)
ys = xs**2
plt.plot(xs,ys)

# %% [markdown]
# $(x+2)^{2}-(x+1)^{2}$ is greater than $(x+1)^{2}-x^{2}$

# %% [markdown]
# ![Slope](<slope.svg>)

# %% [markdown]
# $\frac{y_2-y_1}{x_2-x_1}$

# %%
#Find 2 points close to 5
x1 = 5- 1e-8
x2 = 5 + 1e-8


#Calculate corresponding y values
y1 = x1**2
y2 = x2**2

(y2 - y1) / (x2 - x1)
# Out:
# 10.0

# %% [markdown]
# $f'(5) = 10$

# %%
ys = xs*2

#plot the derivative
plt.plot(xs,ys)
